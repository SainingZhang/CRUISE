# %%
from tqdm import tqdm
import numpy as np
import cv2
import shutil
import torch
import os
import pandas as pd
import json


save_dir = "/mnt/xuhr/street-gs/output/dair_seq_0017/exp_1/train/ours_100000/exp_2025-02-25_18-09"


specified_sequence_id = save_dir.split('dair_seq_')[1].split('/')[0]

sequence_name = f"{specified_sequence_id}_gen_0"

v2x_seq_spd_path = "/mnt/zhangsn/data/V2X-Seq-SPD"

generate_path = f"/mnt/zhangsn/data/generated_dataset/{specified_sequence_id}/{sequence_name}"

os.makedirs(generate_path, exist_ok=True)

# %%
generate_path
# Out:
# '/mnt/zhangsn/data/generated_dataset/0017/0017_gen_0'

# %%
with torch.no_grad():            

        with open(f'{v2x_seq_spd_path}/cooperative/data_info.json', 'r') as file:
                data_info_data = json.load(file)
                cooperative_data_info_df = pd.DataFrame(data_info_data)
                cooperative_filtered_df = cooperative_data_info_df[cooperative_data_info_df['infrastructure_sequence'] == specified_sequence_id]


        with open(f'{v2x_seq_spd_path}/infrastructure-side/data_info.json', 'r') as file:
                data_info_data = json.load(file)
                infrastructure_data_info_df = pd.DataFrame(data_info_data)

                infrastructure_filtered_df = infrastructure_data_info_df[infrastructure_data_info_df['sequence_id'] == specified_sequence_id]
                infrastructure_filtered_df = infrastructure_filtered_df.loc[infrastructure_filtered_df['frame_id'].isin(cooperative_filtered_df['infrastructure_frame'])]


        with open(f'{v2x_seq_spd_path}/vehicle-side/data_info.json', 'r') as file:
                data_info_data = json.load(file)
                vehicle_data_info_df = pd.DataFrame(data_info_data)
                vehicle_filtered_df = vehicle_data_info_df[vehicle_data_info_df['sequence_id'] == specified_sequence_id]
                vehicle_filtered_df = vehicle_filtered_df.loc[vehicle_filtered_df['frame_id'].isin(cooperative_filtered_df['vehicle_frame'])]

        infrastructure_calib_camera_intrinsic_paths = infrastructure_filtered_df['calib_camera_intrinsic_path'].tolist()
        vehicle_calib_camera_intrinsic_paths = vehicle_filtered_df['calib_camera_intrinsic_path'].tolist()

        car_list_infrastructure = [os.path.splitext(os.path.basename(path))[0] for path in infrastructure_calib_camera_intrinsic_paths]
        car_list_vehicle = [os.path.splitext(os.path.basename(path))[0] for path in vehicle_calib_camera_intrinsic_paths]

        vehicle_filtered_df.reset_index(drop=True, inplace=True)
        infrastructure_filtered_df.reset_index(drop=True, inplace=True)
        
        
generate_new_dataset = 1

if generate_new_dataset:
    target_dir_1 = os.path.join(generate_path, 'vehicle-side', 'image')
    target_dir_2 = os.path.join(generate_path, 'infrastructure-side', 'image')

    os.makedirs(target_dir_1, exist_ok=True)
    os.makedirs(target_dir_2, exist_ok=True)

    frame_list = []

    for filename in os.listdir(save_dir+"/rgb"):
        if 'rgb.png' in filename:
            parts = filename.split('_')
            frame_id = parts[0] 

            if frame_id not in frame_list:
                frame_list.append(frame_id)

    frame_list.sort()

    for filename in os.listdir(save_dir+"/rgb"):
        if 'rgb.png' in filename:
            parts = filename.split('_')
            frame_id = parts[0]  
            view_id = parts[1]  

            index = frame_list.index(frame_id)
            new_filename = f'{index:06}.png'  

            original_path = os.path.join(save_dir,"rgb", filename)

            if view_id == '0':
                target_path = os.path.join(target_dir_1, new_filename)
                shutil.copy2(original_path, target_path)
            elif view_id == '1':
                target_path = os.path.join(target_dir_2, new_filename)
                shutil.copy2(original_path, target_path)

            print(f"Copied {filename} as {new_filename} to the target directory.")

    print("All files processed.")
# Out:
# Copied 000040_0_rgb.png as 000040.png to the target directory.
# Copied 000060_0_rgb.png as 000060.png to the target directory.
# Copied 000099_1_rgb.png as 000099.png to the target directory.
# Copied 000044_1_rgb.png as 000044.png to the target directory.
# Copied 000052_1_rgb.png as 000052.png to the target directory.
# Copied 000066_1_rgb.png as 000066.png to the target directory.
# Copied 000014_0_rgb.png as 000014.png to the target directory.
# Copied 000024_0_rgb.png as 000024.png to the target directory.
# Copied 000002_0_rgb.png as 000002.png to the target directory.
# Copied 000042_1_rgb.png as 000042.png to the target directory.
# Copied 000063_0_rgb.png as 000063.png to the target directory.
# Copied 000080_1_rgb.png as 000080.png to the target directory.
# Copied 000093_1_rgb.png as 000093.png to the target directory.
# Copied 000043_1_rgb.png as 000043.png to the target directory.
# Copied 000012_1_rgb.png as 000012.png to the target directory.
# Copied 000011_1_rgb.png as 000011.png to the target directory.
# Copied 000004_0_rgb.png as 000004.png to the target directory.
# Copied 000079_1_rgb.png as 000079.png to the target directory.
# Copied 000003_1_rgb.png as 000003.png to the target directory.
# Copied 000008_0_rgb.png as 000008.png to the target directory.
# Copied 000081_1_rgb.png as 000081.png to the target directory.
# Copied 000005_0_rgb.png as 000005.png to the target directory.
# Copied 000022_1_rgb.png as 000022.png to the target directory.
# Copied 000067_1_rgb.png as 000067.png to the target directory.
# Copied 000065_1_rgb.png as 000065.png to the target directory.
# Copied 000025_1_rgb.png as 000025.png to the target directory.
# Copied 000017_1_rgb.png as 000017.png to the target directory.
# Copied 000030_0_rgb.png as 000030.png to the target directory.
# Copied 000010_1_rgb.png as 000010.png to the target directory.
# Copied 000002_1_rgb.png as 000002.png to the target directory.
# Copied 000068_1_rgb.png as 000068.png to the target directory.
# Copied 000030_1_rgb.png as 000030.png to the target directory.
# Copied 000027_0_rgb.png as 000027.png to the target directory.
# Copied 000090_1_rgb.png as 000090.png to the target directory.
# Copied 000064_1_rgb.png as 000064.png to the target directory.
# Copied 000051_0_rgb.png as 000051.png to the target directory.
# Copied 000069_1_rgb.png as 000069.png to the target directory.
# Copied 000025_0_rgb.png as 000025.png to the target directory.
# Copied 000073_1_rgb.png as 000073.png to the target directory.
# Copied 000000_1_rgb.png as 000000.png to the target directory.
# Copied 000051_1_rgb.png as 000051.png to the target directory.
# Copied 000096_1_rgb.png as 000096.png to the target directory.
# Copied 000014_1_rgb.png as 000014.png to the target directory.
# Copied 000022_0_rgb.png as 000022.png to the target directory.
# Copied 000077_0_rgb.png as 000077.png to the target directory.
# Copied 000038_0_rgb.png as 000038.png to the target directory.
# Copied 000072_1_rgb.png as 000072.png to the target directory.
# Copied 000021_0_rgb.png as 000021.png to the target directory.
# Copied 000008_1_rgb.png as 000008.png to the target directory.
# Copied 000089_0_rgb.png as 000089.png to the target directory.
# Copied 000035_1_rgb.png as 000035.png to the target directory.
# Copied 000071_1_rgb.png as 000071.png to the target directory.
# Copied 000036_0_rgb.png as 000036.png to the target directory.
# Copied 000057_0_rgb.png as 000057.png to the target directory.
# Copied 000064_0_rgb.png as 000064.png to the target directory.
# Copied 000083_1_rgb.png as 000083.png to the target directory.
# Copied 000088_1_rgb.png as 000088.png to the target directory.
# Copied 000071_0_rgb.png as 000071.png to the target directory.
# Copied 000006_0_rgb.png as 000006.png to the target directory.
# Copied 000032_0_rgb.png as 000032.png to the target directory.
# Copied 000037_1_rgb.png as 000037.png to the target directory.
# Copied 000087_1_rgb.png as 000087.png to the target directory.
# Copied 000093_0_rgb.png as 000093.png to the target directory.
# Copied 000020_0_rgb.png as 000020.png to the target directory.
# Copied 000029_1_rgb.png as 000029.png to the target directory.
# Copied 000067_0_rgb.png as 000067.png to the target directory.
# Copied 000084_1_rgb.png as 000084.png to the target directory.
# Copied 000049_1_rgb.png as 000049.png to the target directory.
# Copied 000031_1_rgb.png as 000031.png to the target directory.
# Copied 000037_0_rgb.png as 000037.png to the target directory.
# Copied 000054_0_rgb.png as 000054.png to the target directory.
# Copied 000004_1_rgb.png as 000004.png to the target directory.
# Copied 000013_1_rgb.png as 000013.png to the target directory.
# Copied 000100_1_rgb.png as 000100.png to the target directory.
# Copied 000029_0_rgb.png as 000029.png to the target directory.
# Copied 000048_0_rgb.png as 000048.png to the target directory.
# Copied 000059_0_rgb.png as 000059.png to the target directory.
# Copied 000079_0_rgb.png as 000079.png to the target directory.
# Copied 000098_0_rgb.png as 000098.png to the target directory.
# Copied 000047_0_rgb.png as 000047.png to the target directory.
# Copied 000062_0_rgb.png as 000062.png to the target directory.
# Copied 000038_1_rgb.png as 000038.png to the target directory.
# Copied 000070_1_rgb.png as 000070.png to the target directory.
# Copied 000047_1_rgb.png as 000047.png to the target directory.
# Copied 000046_1_rgb.png as 000046.png to the target directory.
# Copied 000023_1_rgb.png as 000023.png to the target directory.
# Copied 000056_0_rgb.png as 000056.png to the target directory.
# Copied 000068_0_rgb.png as 000068.png to the target directory.
# Copied 000086_1_rgb.png as 000086.png to the target directory.
# Copied 000013_0_rgb.png as 000013.png to the target directory.
# Copied 000007_1_rgb.png as 000007.png to the target directory.
# Copied 000007_0_rgb.png as 000007.png to the target directory.
# Copied 000039_0_rgb.png as 000039.png to the target directory.
# Copied 000100_0_rgb.png as 000100.png to the target directory.
# Copied 000040_1_rgb.png as 000040.png to the target directory.
# Copied 000015_0_rgb.png as 000015.png to the target directory.
# Copied 000045_1_rgb.png as 000045.png to the target directory.
# Copied 000041_0_rgb.png as 000041.png to the target directory.
# Copied 000018_0_rgb.png as 000018.png to the target directory.
# Copied 000033_1_rgb.png as 000033.png to the target directory.
# Copied 000076_1_rgb.png as 000076.png to the target directory.
# Copied 000082_1_rgb.png as 000082.png to the target directory.
# Copied 000016_1_rgb.png as 000016.png to the target directory.
# Copied 000092_0_rgb.png as 000092.png to the target directory.
# Copied 000041_1_rgb.png as 000041.png to the target directory.
# Copied 000095_0_rgb.png as 000095.png to the target directory.
# Copied 000060_1_rgb.png as 000060.png to the target directory.
# Copied 000050_0_rgb.png as 000050.png to the target directory.
# Copied 000077_1_rgb.png as 000077.png to the target directory.
# Copied 000088_0_rgb.png as 000088.png to the target directory.
# Copied 000032_1_rgb.png as 000032.png to the target directory.
# Copied 000069_0_rgb.png as 000069.png to the target directory.
# Copied 000062_1_rgb.png as 000062.png to the target directory.
# Copied 000081_0_rgb.png as 000081.png to the target directory.
# Copied 000078_1_rgb.png as 000078.png to the target directory.
# Copied 000074_1_rgb.png as 000074.png to the target directory.
# Copied 000087_0_rgb.png as 000087.png to the target directory.
# Copied 000001_0_rgb.png as 000001.png to the target directory.
# Copied 000044_0_rgb.png as 000044.png to the target directory.
# Copied 000092_1_rgb.png as 000092.png to the target directory.
# Copied 000045_0_rgb.png as 000045.png to the target directory.
# Copied 000010_0_rgb.png as 000010.png to the target directory.
# Copied 000043_0_rgb.png as 000043.png to the target directory.
# Copied 000084_0_rgb.png as 000084.png to the target directory.
# Copied 000096_0_rgb.png as 000096.png to the target directory.
# Copied 000023_0_rgb.png as 000023.png to the target directory.
# Copied 000098_1_rgb.png as 000098.png to the target directory.
# Copied 000090_0_rgb.png as 000090.png to the target directory.
# Copied 000078_0_rgb.png as 000078.png to the target directory.
# Copied 000058_0_rgb.png as 000058.png to the target directory.
# Copied 000046_0_rgb.png as 000046.png to the target directory.
# Copied 000049_0_rgb.png as 000049.png to the target directory.
# Copied 000053_0_rgb.png as 000053.png to the target directory.
# Copied 000055_0_rgb.png as 000055.png to the target directory.
# Copied 000066_0_rgb.png as 000066.png to the target directory.
# Copied 000026_1_rgb.png as 000026.png to the target directory.
# Copied 000073_0_rgb.png as 000073.png to the target directory.
# Copied 000042_0_rgb.png as 000042.png to the target directory.
# Copied 000072_0_rgb.png as 000072.png to the target directory.
# Copied 000001_1_rgb.png as 000001.png to the target directory.
# Copied 000034_0_rgb.png as 000034.png to the target directory.
# Copied 000006_1_rgb.png as 000006.png to the target directory.
# Copied 000028_0_rgb.png as 000028.png to the target directory.
# Copied 000016_0_rgb.png as 000016.png to the target directory.
# Copied 000086_0_rgb.png as 000086.png to the target directory.
# Copied 000018_1_rgb.png as 000018.png to the target directory.
# Copied 000009_0_rgb.png as 000009.png to the target directory.
# Copied 000059_1_rgb.png as 000059.png to the target directory.
# Copied 000055_1_rgb.png as 000055.png to the target directory.
# Copied 000019_0_rgb.png as 000019.png to the target directory.
# Copied 000021_1_rgb.png as 000021.png to the target directory.
# Copied 000011_0_rgb.png as 000011.png to the target directory.
# Copied 000034_1_rgb.png as 000034.png to the target directory.
# Copied 000097_0_rgb.png as 000097.png to the target directory.
# Copied 000076_0_rgb.png as 000076.png to the target directory.
# Copied 000028_1_rgb.png as 000028.png to the target directory.
# Copied 000035_0_rgb.png as 000035.png to the target directory.
# Copied 000099_0_rgb.png as 000099.png to the target directory.
# Copied 000054_1_rgb.png as 000054.png to the target directory.
# Copied 000056_1_rgb.png as 000056.png to the target directory.
# Copied 000031_0_rgb.png as 000031.png to the target directory.
# Copied 000085_1_rgb.png as 000085.png to the target directory.
# Copied 000070_0_rgb.png as 000070.png to the target directory.
# Copied 000091_0_rgb.png as 000091.png to the target directory.
# Copied 000012_0_rgb.png as 000012.png to the target directory.
# Copied 000005_1_rgb.png as 000005.png to the target directory.
# Copied 000063_1_rgb.png as 000063.png to the target directory.
# Copied 000039_1_rgb.png as 000039.png to the target directory.
# Copied 000020_1_rgb.png as 000020.png to the target directory.
# Copied 000061_1_rgb.png as 000061.png to the target directory.
# Copied 000058_1_rgb.png as 000058.png to the target directory.
# Copied 000085_0_rgb.png as 000085.png to the target directory.
# Copied 000019_1_rgb.png as 000019.png to the target directory.
# Copied 000082_0_rgb.png as 000082.png to the target directory.
# Copied 000075_1_rgb.png as 000075.png to the target directory.
# Copied 000057_1_rgb.png as 000057.png to the target directory.
# Copied 000009_1_rgb.png as 000009.png to the target directory.
# Copied 000026_0_rgb.png as 000026.png to the target directory.
# Copied 000065_0_rgb.png as 000065.png to the target directory.
# Copied 000097_1_rgb.png as 000097.png to the target directory.
# Copied 000095_1_rgb.png as 000095.png to the target directory.
# Copied 000033_0_rgb.png as 000033.png to the target directory.
# Copied 000089_1_rgb.png as 000089.png to the target directory.
# Copied 000080_0_rgb.png as 000080.png to the target directory.
# Copied 000050_1_rgb.png as 000050.png to the target directory.
# Copied 000048_1_rgb.png as 000048.png to the target directory.
# Copied 000036_1_rgb.png as 000036.png to the target directory.
# Copied 000017_0_rgb.png as 000017.png to the target directory.
# Copied 000061_0_rgb.png as 000061.png to the target directory.
# Copied 000000_0_rgb.png as 000000.png to the target directory.
# Copied 000094_0_rgb.png as 000094.png to the target directory.
# Copied 000083_0_rgb.png as 000083.png to the target directory.
# Copied 000003_0_rgb.png as 000003.png to the target directory.
# Copied 000027_1_rgb.png as 000027.png to the target directory.
# Copied 000074_0_rgb.png as 000074.png to the target directory.
# Copied 000053_1_rgb.png as 000053.png to the target directory.
# Copied 000052_0_rgb.png as 000052.png to the target directory.
# Copied 000015_1_rgb.png as 000015.png to the target directory.
# Copied 000094_1_rgb.png as 000094.png to the target directory.
# Copied 000024_1_rgb.png as 000024.png to the target directory.
# Copied 000075_0_rgb.png as 000075.png to the target directory.
# Copied 000091_1_rgb.png as 000091.png to the target directory.
# All files processed.

# %%
target_size = (1920, 1080)

def process_images(image_dir):
    """
    Process the image; if the size is 1600x900, scale it to 1920x1080, convert it to jpg format for saving, and delete the original png image.
    """
    image_files = [f for f in os.listdir(image_dir) if f.endswith('.png')]

    for image_file in tqdm(image_files, desc="Processing images"):
        image_path = os.path.join(image_dir, image_file)
        image = cv2.imread(image_path)

        if image is not None:
            h, w = image.shape[:2]
            if (w, h) == (1920, 1080):
                new_image_path = os.path.splitext(image_path)[0] + ".jpg"
                cv2.imwrite(new_image_path, image, [
                            int(cv2.IMWRITE_JPEG_QUALITY), 95])
                os.remove(image_path)
            elif (w, h) == (1600, 900):  
                resized_image = cv2.resize(
                    image, target_size, interpolation=cv2.INTER_LINEAR)
                new_image_path = os.path.splitext(image_path)[0] + ".jpg"
                cv2.imwrite(new_image_path, resized_image, [
                            int(cv2.IMWRITE_JPEG_QUALITY), 95])
                os.remove(image_path)
            else:
                print(f"跳过图片 {image_file}, 尺寸 {w}x{h} 不是 1920x1080 或 1600x900")
        else:
            print(f"读取图片失败 {image_file}")


image_dirs = [
    target_dir_1,
    target_dir_2
]

for image_dir in image_dirs:
    process_images(image_dir)
# Out:
# Processing images: 100%|██████████| 101/101 [00:05<00:00, 19.18it/s]
# Processing images: 100%|██████████| 101/101 [00:06<00:00, 15.48it/s]

# %% [markdown]
# 核心需要修改的

# %%
import os
import json
from tqdm import tqdm
import numpy as np

def read_json_file(file_path):
    with open(file_path, 'r') as f:
        data = json.load(f)
    return data

def process_annotations_with_modifications(annotations, modified_actors_dict):
    """处理标注数据，应用修改后的bbox和位置偏移"""
    new_annotations = []
    
    for ann in annotations:
        track_id = ann['track_id']
        if track_id in modified_actors_dict:
            modified_actor = modified_actors_dict[track_id]
            
            # 更新3d_dimensions（bbox）
            ann['3d_dimensions']['l'] = modified_actor['bbox']['length']
            ann['3d_dimensions']['w'] = modified_actor['bbox']['width']
            ann['3d_dimensions']['h'] = modified_actor['bbox']['height']
            
            # 应用center_offset到3d_location
            if modified_actor['center_offset'] is not None:
                ann['3d_location']['x'] += modified_actor['center_offset'][0]
                ann['3d_location']['y'] += modified_actor['center_offset'][1]
                ann['3d_location']['z'] += modified_actor['center_offset'][2]
        
        new_annotations.append(ann)
    
    return new_annotations

def generate_dataset(source_path, generate_path, frame_list, modified_actors_path, car_list_vehicle, car_list_infrastructure):
    # 读取modified_actors.json
    modified_actors_data = read_json_file(modified_actors_path)
    # 转换为字典格式，方便查找
    modified_actors_dict = {str(int(actor['track_id'])).zfill(6): actor for actor in modified_actors_data}
    
    rename_idx = 0
    exclude_list = []
    exclude_list_formatted = []
    exclude_list_formatted_car = []
    exclude_list_formatted_road = []
    
    for obj in exclude_list:
        number = obj.split('_')[1]
        formatted_number = str(int(number)).zfill(6)
        exclude_list_formatted.append(formatted_number)

    # 创建必要的目录
    os.makedirs(os.path.join(generate_path, 'cooperative', 'label'), exist_ok=True)
    os.makedirs(os.path.join(generate_path, 'vehicle-side', 'label', 'lidar'), exist_ok=True)
    os.makedirs(os.path.join(generate_path, 'vehicle-side', 'label', 'camera'), exist_ok=True)
    os.makedirs(os.path.join(generate_path, 'infrastructure-side', 'label', 'camera'), exist_ok=True)
    os.makedirs(os.path.join(generate_path, 'infrastructure-side', 'label', 'virtuallidar'), exist_ok=True)

    for idx, car_id in tqdm(enumerate(car_list_vehicle), desc="Processing annotations"):
        if str(int(idx)).zfill(6) not in frame_list:
            continue
            
        # 读取所有标注文件
        coop_annotations = read_json_file(os.path.join(
            source_path, 'cooperative', 'label', car_list_vehicle[idx] + '.json'))
        car_annotations_cam = read_json_file(os.path.join(
            source_path, 'vehicle-side', 'label', 'camera', car_list_vehicle[idx] + '.json'))
        road_annotations_cam = read_json_file(os.path.join(
            source_path, 'infrastructure-side', 'label', 'camera', car_list_infrastructure[idx] + '.json'))
        car_annotations_lidar = read_json_file(os.path.join(
            source_path, 'vehicle-side', 'label', 'lidar', car_list_vehicle[idx] + '.json'))
        road_annotations_lidar = read_json_file(os.path.join(
            source_path, 'infrastructure-side', 'label', 'virtuallidar', car_list_infrastructure[idx] + '.json'))

        # 处理标注，应用修改
        new_annotations_coop = []
        new_annotations_car_cam = []
        new_annotations_road_cam = []
        new_annotations_car_lidar = []
        new_annotations_road_lidar = []

        # 处理cooperative标注
        for ann in coop_annotations:
            if ann['track_id'] not in exclude_list_formatted:
                # 更新frame_id
                ann['veh_frame_id'] = str(int(rename_idx)).zfill(6)
                ann['inf_frame_id'] = str(int(rename_idx)).zfill(6)
                
                # 应用修改（如果存在）
                if ann['track_id'] in modified_actors_dict:
                    modified_actor = modified_actors_dict[ann['track_id']]
                    ann['3d_dimensions']['l'] = modified_actor['bbox']['length']
                    ann['3d_dimensions']['w'] = modified_actor['bbox']['width']
                    ann['3d_dimensions']['h'] = modified_actor['bbox']['height']
                    if modified_actor['center_offset'] is not None:
                        ann['3d_location']['x'] += modified_actor['center_offset'][0]
                        ann['3d_location']['y'] += modified_actor['center_offset'][1]
                        ann['3d_location']['z'] += modified_actor['center_offset'][2]
                    print("ann['track_id']:", ann['track_id'])
                
                new_annotations_coop.append(ann)
            elif ann['track_id'] in exclude_list_formatted:
                exclude_list_formatted_car.append(ann["veh_track_id"])
                exclude_list_formatted_road.append(ann["inf_track_id"])

        # 处理其他标注
        for ann in car_annotations_cam:
            if ann['track_id'] not in exclude_list_formatted_car:
                if ann['track_id'] in modified_actors_dict:
                    modified_actor = modified_actors_dict[ann['track_id']]
                    ann['3d_dimensions']['l'] = modified_actor['bbox']['length']
                    ann['3d_dimensions']['w'] = modified_actor['bbox']['width']
                    ann['3d_dimensions']['h'] = modified_actor['bbox']['height']
                    if modified_actor['center_offset'] is not None:
                        ann['3d_location']['x'] += modified_actor['center_offset'][0]
                        ann['3d_location']['y'] += modified_actor['center_offset'][1]
                        ann['3d_location']['z'] += modified_actor['center_offset'][2]
                new_annotations_car_cam.append(ann)

        for ann in road_annotations_cam:
            if ann['track_id'] not in exclude_list_formatted_road:
                if ann['track_id'] in modified_actors_dict:
                    modified_actor = modified_actors_dict[ann['track_id']]
                    ann['3d_dimensions']['l'] = modified_actor['bbox']['length']
                    ann['3d_dimensions']['w'] = modified_actor['bbox']['width']
                    ann['3d_dimensions']['h'] = modified_actor['bbox']['height']
                    if modified_actor['center_offset'] is not None:
                        ann['3d_location']['x'] += modified_actor['center_offset'][0]
                        ann['3d_location']['y'] += modified_actor['center_offset'][1]
                        ann['3d_location']['z'] += modified_actor['center_offset'][2]
                new_annotations_road_cam.append(ann)

        for ann in car_annotations_lidar:
            if ann['track_id'] not in exclude_list_formatted_car:
                if ann['track_id'] in modified_actors_dict:
                    modified_actor = modified_actors_dict[ann['track_id']]
                    ann['3d_dimensions']['l'] = modified_actor['bbox']['length']
                    ann['3d_dimensions']['w'] = modified_actor['bbox']['width']
                    ann['3d_dimensions']['h'] = modified_actor['bbox']['height']
                    if modified_actor['center_offset'] is not None:
                        ann['3d_location']['x'] += modified_actor['center_offset'][0]
                        ann['3d_location']['y'] += modified_actor['center_offset'][1]
                        ann['3d_location']['z'] += modified_actor['center_offset'][2]
                new_annotations_car_lidar.append(ann)

        for ann in road_annotations_lidar:
            if ann['track_id'] not in exclude_list_formatted_road:
                if ann['track_id'] in modified_actors_dict:
                    modified_actor = modified_actors_dict[ann['track_id']]
                    ann['3d_dimensions']['l'] = modified_actor['bbox']['length']
                    ann['3d_dimensions']['w'] = modified_actor['bbox']['width']
                    ann['3d_dimensions']['h'] = modified_actor['bbox']['height']
                    if modified_actor['center_offset'] is not None:
                        ann['3d_location']['x'] += modified_actor['center_offset'][0]
                        ann['3d_location']['y'] += modified_actor['center_offset'][1]
                        ann['3d_location']['z'] += modified_actor['center_offset'][2]
                new_annotations_road_lidar.append(ann)

        # 保存处理后的标注
        coop_annotation_path = os.path.join(
            generate_path, 'cooperative', 'label', str(int(rename_idx)).zfill(6) + '.json')
        vehicle_annotation_path_cam = os.path.join(
            generate_path, 'vehicle-side', 'label', 'camera', str(int(rename_idx)).zfill(6) + '.json')
        infrastructure_annotation_path_cam = os.path.join(
            generate_path, 'infrastructure-side', 'label', 'camera', str(int(rename_idx)).zfill(6) + '.json')
        vehicle_annotation_path_lidar = os.path.join(
            generate_path, 'vehicle-side', 'label', 'lidar', str(int(rename_idx)).zfill(6) + '.json')
        infrastructure_annotation_path_lidar = os.path.join(
            generate_path, 'infrastructure-side', 'label', 'virtuallidar', str(int(rename_idx)).zfill(6) + '.json')

        # 写入文件
        with open(coop_annotation_path, 'w') as f:
            json.dump(new_annotations_coop, f, indent=4)
        with open(vehicle_annotation_path_cam, 'w') as f:
            json.dump(new_annotations_car_cam, f, indent=4)
        with open(infrastructure_annotation_path_cam, 'w') as f:
            json.dump(new_annotations_road_cam, f, indent=4)
        with open(vehicle_annotation_path_lidar, 'w') as f:
            json.dump(new_annotations_car_lidar, f, indent=4)
        with open(infrastructure_annotation_path_lidar, 'w') as f:
            json.dump(new_annotations_road_lidar, f, indent=4)

        rename_idx += 1

# 使用示例

modified_actors_path = save_dir + "/modified_actors.json"

source_path = f"{v2x_seq_spd_path}"

generate_dataset(
    source_path,
    generate_path,
    frame_list,
    modified_actors_path,
    car_list_vehicle,
    car_list_infrastructure
)
# Out:
# Processing annotations: 9it [00:00, 80.07it/s]
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# Processing annotations: 27it [00:00, 82.28it/s]
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007610
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007624
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007624
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007612
# ann['track_id']: 007613
# ann['track_id']: 007615
# ann['track_id']: 007616
# ann['track_id']: 007617
# ann['track_id']: 007618
# ann['track_id']: 007620
# ann['track_id']: 007621
# ann['track_id']: 007617
# ann['track_id']: 007634
# ann['track_id']: 007636
# ann['track_id']: 007637
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007634
# ann['track_id']: 007636
# ann['track_id']: 007637
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007634
# ann['track_id']: 007636
# ann['track_id']: 007637
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007634
# ann['track_id']: 007636
# ann['track_id']: 007637
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007634
# ann['track_id']: 007636
# ann['track_id']: 007637
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# Processing annotations: 45it [00:00, 85.42it/s]
# ann['track_id']: 007617
# ann['track_id']: 007634
# ann['track_id']: 007636
# ann['track_id']: 007637
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007634
# ann['track_id']: 007636
# ann['track_id']: 007637
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007640
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007646
# Processing annotations: 65it [00:00, 90.71it/s]
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007639
# ann['track_id']: 007640
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007640
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007640
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007624
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# Processing annotations: 85it [00:00, 93.17it/s]
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007646
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007642
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007642
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007642
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007642
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007642
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007642
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007640
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007638
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007649
# Processing annotations: 101it [00:01, 90.40it/s]
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007640
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007640
# ann['track_id']: 007649
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007640
# ann['track_id']: 007649
# ann['track_id']: 007650
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007649
# ann['track_id']: 007650
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007640
# ann['track_id']: 007649
# ann['track_id']: 007650
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007640
# ann['track_id']: 007649
# ann['track_id']: 007650
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007649
# ann['track_id']: 007650
# ann['track_id']: 007617
# ann['track_id']: 007636
# ann['track_id']: 007649
# ann['track_id']: 007650

# %%
# def read_json_file(file_path):
#     with open(file_path, 'r') as f:
#         data = json.load(f)
#     return data

# source_path = f"{v2x_seq_spd_path}"
# car_list = car_list_vehicle

# rename_idx = 0

# exclude_list = []
# exclude_list_formatted = []
# exclude_list_formatted_car = []
# exclude_list_formatted_road = []
# for obj in exclude_list:
#     number = obj.split('_')[1]
#     formatted_number = str(int(number)).zfill(6)
#     exclude_list_formatted.append(formatted_number)


# os.makedirs(os.path.join(generate_path, 'cooperative', 'label'), exist_ok=True)
# os.makedirs(os.path.join(generate_path, 'vehicle-side',
#             'label', 'lidar'), exist_ok=True)
# os.makedirs(os.path.join(generate_path, 'vehicle-side',
#             'label', 'camera'), exist_ok=True)
# os.makedirs(os.path.join(generate_path, 'infrastructure-side',
#             'label', 'camera'), exist_ok=True)
# os.makedirs(os.path.join(generate_path, 'infrastructure-side',
#             'label', 'virtuallidar'), exist_ok=True)

# for idx, car_id in tqdm(enumerate(car_list), desc="Loading data"):

#     if str(int(idx)).zfill(6) not in frame_list:
#         continue
#     else:
#         coop_annotations = read_json_file(os.path.join(
#             source_path, 'cooperative', 'label', car_list_vehicle[idx] + '.json'))
#         car_annotations_cam = read_json_file(os.path.join(
#             source_path, 'vehicle-side', 'label', 'camera', car_list_vehicle[idx] + '.json'))
#         print(os.path.join(source_path, 'infrastructure-side', 'label',
#               'camera', car_list_infrastructure[idx] + '.json'))
#         road_annotations_cam = read_json_file(os.path.join(
#             source_path, 'infrastructure-side', 'label', 'camera', car_list_infrastructure[idx] + '.json'))

#         car_annotations_lidar = read_json_file(os.path.join(
#             source_path, 'vehicle-side', 'label', 'lidar', car_list_vehicle[idx] + '.json'))
#         road_annotations_lidar = read_json_file(os.path.join(
#             source_path, 'infrastructure-side', 'label', 'virtuallidar', car_list_infrastructure[idx] + '.json'))

#         new_annotations_car_cam = []
#         new_annotations_road_cam = []
#         new_annotations_car_lidar = []
#         new_annotations_road_lidar = []
#         new_annotations_coop = []

#         for ann in coop_annotations:

#             if ann['track_id'] not in exclude_list_formatted:
#                 ann['veh_frame_id'] = str(int(rename_idx)).zfill(6)
#                 ann['inf_frame_id'] = str(int(rename_idx)).zfill(6)

#                 new_annotations_coop.append(ann)

#             elif ann['track_id'] in exclude_list_formatted:
#                 exclude_list_formatted_car.append(ann["veh_track_id"])
#                 exclude_list_formatted_road.append(ann["inf_track_id"])

#         for ann in car_annotations_cam:
#             if ann['track_id'] not in exclude_list_formatted_car:
#                 new_annotations_car_cam.append(ann)

#         for ann in road_annotations_cam:
#             if ann['track_id'] not in exclude_list_formatted_road:
#                 new_annotations_road_cam.append(ann)

#         for ann in car_annotations_lidar:
#             if ann['track_id'] not in exclude_list_formatted_car:
#                 new_annotations_car_lidar.append(ann)

#         for ann in road_annotations_lidar:
#             if ann['track_id'] not in exclude_list_formatted_road:
#                 new_annotations_road_lidar.append(ann)

#         coop_annotation_path = os.path.join(
#             generate_path, 'cooperative', 'label',  str(int(rename_idx)).zfill(6) + '.json')

#         vehicle_annotation_path_cam = os.path.join(
#             generate_path, 'vehicle-side', 'label', 'camera',  str(int(rename_idx)).zfill(6) + '.json')

#         infrastructure_annotation_path_cam = os.path.join(
#             generate_path, 'infrastructure-side', 'label', 'camera', str(int(rename_idx)).zfill(6) + '.json')

#         vehicle_annotation_path_lidar = os.path.join(
#             generate_path, 'vehicle-side', 'label', 'lidar',  str(int(rename_idx)).zfill(6) + '.json')

#         infrastructure_annotation_path_lidar = os.path.join(
#             generate_path, 'infrastructure-side', 'label', 'virtuallidar', str(int(rename_idx)).zfill(6) + '.json')

#         with open(coop_annotation_path, 'w') as f:
#             json.dump(new_annotations_coop, f, indent=4)
#         with open(vehicle_annotation_path_cam, 'w') as f:
#             json.dump(new_annotations_car_cam, f, indent=4)
#         with open(infrastructure_annotation_path_cam, 'w') as f:
#             json.dump(new_annotations_road_cam, f, indent=4)
#         with open(vehicle_annotation_path_lidar, 'w') as f:
#             json.dump(new_annotations_car_lidar, f, indent=4)
#         with open(infrastructure_annotation_path_lidar, 'w') as f:
#             json.dump(new_annotations_road_lidar, f, indent=4)

#         rename_idx += 1
# Out:
# Loading data: 9it [00:00, 88.98it/s]
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004416.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004417.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004418.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004419.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004420.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004421.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004422.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004423.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004424.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004425.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004426.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004427.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004428.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004429.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004430.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004431.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004433.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004434.json
# Loading data: 27it [00:00, 87.75it/s]
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004435.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004436.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004437.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004438.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004439.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004440.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004441.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004442.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004443.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004444.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004445.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004446.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004447.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004448.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004449.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004450.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004451.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004452.json
# Loading data: 45it [00:00, 88.18it/s]
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004453.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004454.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004455.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004456.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004457.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004458.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004459.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004460.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004461.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004462.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004463.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004464.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004465.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004466.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004467.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004468.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004469.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004470.json
# Loading data: 64it [00:00, 88.70it/s]
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004471.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004472.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004473.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004474.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004475.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004476.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004477.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004478.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004479.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004480.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004481.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004482.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004483.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004484.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004485.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004486.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004487.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004488.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004489.json
# Loading data: 84it [00:00, 90.86it/s]
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004490.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004491.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004492.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004493.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004494.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004495.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004496.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004497.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004498.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004499.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004500.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004501.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004502.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004503.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004504.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004505.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004506.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004507.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004508.json
# Loading data: 104it [00:01, 93.33it/s]
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004509.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004510.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004511.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004512.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004513.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004514.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004515.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004516.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004517.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004518.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004519.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004520.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004521.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004522.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004523.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004524.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004525.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004526.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004527.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004528.json
# Loading data: 125it [00:01, 91.59it/s]
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004529.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004530.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004531.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004532.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004533.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004534.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004536.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004537.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004538.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004539.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004546.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004548.json
# /mnt/zhangsn/data/V2X-Seq-SPD/infrastructure-side/label/camera/004549.json

# %%
rename_idx = 0
car_list = car_list_vehicle
target_calib_path_car = generate_path + '/vehicle-side/calib'
target_calib_path_road = generate_path + '/infrastructure-side/calib'

os.makedirs(os.path.join(target_calib_path_car,
            "camera_intrinsic"), exist_ok=True)
os.makedirs(os.path.join(target_calib_path_car,
            "lidar_to_camera"), exist_ok=True)
os.makedirs(os.path.join(target_calib_path_car,
            "lidar_to_novatel"), exist_ok=True)
os.makedirs(os.path.join(target_calib_path_car,
            "novatel_to_world"), exist_ok=True)

os.makedirs(os.path.join(target_calib_path_road,
            "camera_intrinsic"), exist_ok=True)
os.makedirs(os.path.join(target_calib_path_road,
            "virtuallidar_to_camera"), exist_ok=True)
os.makedirs(os.path.join(target_calib_path_road,
            "virtuallidar_to_world"), exist_ok=True)


for idx, car_id in tqdm(enumerate(car_list), desc="Loading data"):
    if str(int(idx)).zfill(6) not in frame_list:
        continue
    else:
        # Read infrastructure and vehicle calibration info
        infrastructure_camera_intrinsics_json = read_json_file(os.path.join(
            source_path, 'infrastructure-side', 'calib', 'camera_intrinsic', car_list_infrastructure[idx]+'.json'))
        infrastructure_lidar_to_camera_json = read_json_file(os.path.join(
            source_path, 'infrastructure-side', 'calib', 'virtuallidar_to_camera', car_list_infrastructure[idx]+'.json'))
        infrastructure_lidar_to_world_json = read_json_file(os.path.join(
            source_path, 'infrastructure-side', 'calib', 'virtuallidar_to_world', car_list_infrastructure[idx]+'.json'))

        # Read vehicle cam info
        vehicle_camera_intrinsics_json = read_json_file(os.path.join(
            source_path, 'vehicle-side', 'calib', 'camera_intrinsic', car_list_vehicle[idx] + '.json'))
        vehicle_lidar_to_camera_json = read_json_file(os.path.join(
            source_path, 'vehicle-side', 'calib', 'lidar_to_camera', car_list_vehicle[idx] + '.json'))
        vehicle_lidar_to_novatel_json = read_json_file(os.path.join(
            source_path, 'vehicle-side', 'calib', 'lidar_to_novatel', car_list_vehicle[idx] + '.json'))  
        vehicle_novatel_to_world_json = read_json_file(os.path.join(
            source_path, 'vehicle-side', 'calib', 'novatel_to_world', car_list_vehicle[idx] + '.json'))  

        image_timestamp = vehicle_filtered_df.loc[idx, 'image_timestamp']

        json_file_car = f"{str(int(rename_idx)).zfill(6)}.json"
        json_file_road = f"{str(int(rename_idx)).zfill(6)}.json"

        target_calib_path_car = generate_path + '/vehicle-side/calib'
        target_calib_path_road = generate_path + '/infrastructure-side/calib'

        with open(os.path.join(target_calib_path_car, "camera_intrinsic", json_file_car), 'w') as f:
            json.dump(vehicle_camera_intrinsics_json, f)
        with open(os.path.join(target_calib_path_car, 'lidar_to_camera', json_file_car), 'w') as f:
            json.dump(vehicle_lidar_to_camera_json, f)
        with open(os.path.join(target_calib_path_car, 'lidar_to_novatel', json_file_car), 'w') as f:
            json.dump(vehicle_lidar_to_novatel_json, f)
        with open(os.path.join(target_calib_path_car, 'novatel_to_world', json_file_car), 'w') as f:
            json.dump(vehicle_novatel_to_world_json, f)

        with open(os.path.join(target_calib_path_road, "camera_intrinsic", json_file_road), 'w') as f:
            json.dump(infrastructure_camera_intrinsics_json, f)
        with open(os.path.join(target_calib_path_road, 'virtuallidar_to_camera', json_file_road), 'w') as f:
            json.dump(infrastructure_lidar_to_camera_json, f)
        with open(os.path.join(target_calib_path_road, 'virtuallidar_to_world', json_file_road), 'w') as f:
            json.dump(infrastructure_lidar_to_world_json, f)

        rename_idx += 1
# Out:
# Loading data: 101it [00:01, 78.21it/s]

# %%
def create_data_info(frame_list, output_path_car, output_path_road):
    data_info_car = []
    data_info_road = []
    for idx, car_id in tqdm(enumerate(frame_list), desc="Creating data info"):
        frame_id = f"{str(0 + idx).zfill(6)}"
        entry_car = {
            "image_path": f"image/{frame_id}.jpg",
            "pointcloud_path": f"velodyne/{frame_id}.pcd",
            "calib_camera_intrinsic_path": f"calib/camera_intrinsic/{frame_id}.json",
            "calib_lidar_to_camera_path": f"calib/lidar_to_camera/{frame_id}.json",
            "calib_lidar_to_novatel_path": f"calib/lidar_to_novatel/{frame_id}.json",
            "calib_novatel_to_world_path": f"calib/novatel_to_world/{frame_id}.json",
            "label_camera_std_path": f"label/camera/{frame_id}.json",
            "label_lidar_std_path": f"label/lidar/{frame_id}.json",
            "intersection_loc": "yizhuang10",
            "image_timestamp": str(1626167047000000 + idx * 100000),
            "pointcloud_timestamp": str(1626167046900000 + idx * 100000),
            "frame_id": frame_id,
            "start_frame_id": f"{str(0 + idx).zfill(6)}",
            "end_frame_id": f"{str(0 + len(frame_list) - 1).zfill(6)}",
            "num_frames": len(frame_list),
            "sequence_id": f"{sequence_name}"
        }
        entry_road = {
            "image_path": f"image/{frame_id}.jpg",
            "pointcloud_path": f"velodyne/{frame_id}.pcd",
            "calib_camera_intrinsic_path": f"calib/camera_intrinsic/{frame_id}.json",
            "calib_virtuallidar_to_camera_path": f"ccalib/virtuallidar_to_camera/{frame_id}.json",
            "calib_virtuallidar_to_world_path": f"calib/virtuallidar_to_world/{frame_id}.json",
            "label_camera_std_path": f"label/camera/{frame_id}.json",
            "label_lidar_std_path": f"label/lidar/{frame_id}.json",
            "intersection_loc": "yizhuang10",
            "image_timestamp": str(1626167047000000 + idx * 100000),
            "pointcloud_timestamp": str(1626167046900000 + idx * 100000),
            "frame_id": frame_id,
            "start_frame_id": f"{str(0 + idx).zfill(6)}",
            "end_frame_id": f"{str(0 + len(frame_list) - 1).zfill(6)}",
            "num_frames": len(frame_list),
            "sequence_id":  f"{sequence_name}"
        }
        data_info_car.append(entry_car)
        data_info_road.append(entry_road)

    with open(output_path_car, 'w') as f:
        json.dump(data_info_car, f, indent=4)
    with open(output_path_road, 'w') as f:
        json.dump(data_info_car, f, indent=4)


output_path_car = os.path.join(generate_path, 'vehicle-side', 'data_info.json')
output_path_road = os.path.join(
    generate_path, 'infrastructure-side', 'data_info.json')
create_data_info(frame_list, output_path_car, output_path_road)
# Out:
# Creating data info: 101it [00:00, 113816.42it/s]

# %%
rename_idx = 0


target_dir_1 = os.path.join(generate_path, 'vehicle-side', 'velodyne')
target_dir_2 = os.path.join(generate_path, 'infrastructure-side', 'velodyne')


os.makedirs(target_dir_1, exist_ok=True)
os.makedirs(target_dir_2, exist_ok=True)


for idx, car_id in tqdm(enumerate(car_list), desc="copying origingal lidar"):
    if str(int(idx)).zfill(6) not in frame_list:
        continue
    else:
        # Read infrastructure and vehicle calibration info
        infrastructure_camera_intrinsics_json = os.path.join(
            source_path, 'infrastructure-side', 'velodyne', car_list_infrastructure[idx]+'.pcd')

        # Read vehicle cam info
        vehicle_camera_intrinsics_json = os.path.join(
            source_path, 'vehicle-side', 'velodyne',  car_list_vehicle[idx] + '.pcd')

        new_filename_car = f'{str(int(rename_idx)).zfill(6)}.pcd'

        target_path_car = os.path.join(target_dir_1, new_filename_car)

        shutil.copy2(infrastructure_camera_intrinsics_json, target_path_car)

        new_filename_road = f'{str(int(rename_idx)).zfill(6)}.pcd'

        target_path_road = os.path.join(target_dir_2, new_filename_road)

        shutil.copy2(vehicle_camera_intrinsics_json, target_path_road)

        rename_idx += 1

print("All files processed.")


def modify_and_copy_data_info(source_path, output_path, start_vehicle_frame=0, start_infrastructure_frame=0, car_list_vehicle=[]):
    """
    
    """
    with open(source_path, 'r') as f:
        data_info = json.load(f)

    vehicle_frame_counter = start_vehicle_frame
    infrastructure_frame_counter = start_infrastructure_frame

    modified_data_info = []

    for entry in tqdm(data_info, desc="Modifying data info"):
        if entry['vehicle_frame'] in car_list_vehicle[int(frame_list[0]):int(frame_list[-1])+1]:
            new_entry = entry.copy()

            
            new_entry['vehicle_frame'] = f"{vehicle_frame_counter:06d}"
            new_entry['infrastructure_frame'] = f"{infrastructure_frame_counter:06d}"
            
            new_entry['vehicle_sequence'] = f"{sequence_name}"
            
            new_entry['infrastructure_sequence'] = f"{sequence_name}"

            
            vehicle_frame_counter += 1
            infrastructure_frame_counter += 1

            modified_data_info.append(new_entry)

    
    with open(output_path, 'w') as f:
        json.dump(modified_data_info, f, indent=4)

    print(f"Modified data_info.json has been appended to {output_path}")


source_data_info_path = os.path.join(
    source_path, 'cooperative', 'data_info.json')  
output_data_info_path = os.path.join(
    generate_path, 'cooperative', 'data_info.json') 
os.makedirs(os.path.dirname(output_data_info_path), exist_ok=True)

modify_and_copy_data_info(source_data_info_path, output_data_info_path, start_vehicle_frame=0,
                          start_infrastructure_frame=0, car_list_vehicle=car_list_vehicle)
# Out:
# copying origingal lidar: 101it [00:01, 82.08it/s]
# All files processed.
# Modifying data info: 100%|██████████| 10761/10761 [00:00<00:00, 611170.01it/s]
# Modified data_info.json has been appended to /mnt/zhangsn/data/generated_dataset/0017/0017_gen_0/cooperative/data_info.json
